# %% [markdown]
# ## Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# ## Adding streamable videos to Notebooks
# Below is an example of how we can add streamable video links to our Notebooks.
# We pass in the ***video id***, ***width*** and ***height*** of the video.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('pXOek_1TUss', width=1000, height=450)

# %% [markdown]
# This is from my personal YouTube channel. Just a song that I covered. lol :P
#
# Ok now lets get to work!
#
# Lets work on the *iris data* again.

# %%
filepath = 'data/iris.csv'
df = pd.read_csv(filepath, index_col='Id')
df.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %% [markdown]
# ## Data exploration
# Lets see if there is any relationship between `Petal Length` and `Sepal Width`.

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x=df['Petal Length (cm)'], y=df['Sepal Width (cm)'], hue=df['Species'])
